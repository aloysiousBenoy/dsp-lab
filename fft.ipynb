# %%
from scipy.fft import fft
import numpy as  np
import matplotlib.pyplot as plt

# %%
x =  np.arange(0,10,0.01)

y = np.sin(5*np.pi*x)

w  = fft(y)


# plt.plot(x,y)
# plt.show()
# print(w)

plt.stem(w)
plt.show()
